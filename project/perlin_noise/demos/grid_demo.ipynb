# %% [markdown]
# # Main and subgrid generation demo

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
out = './out/'
data = './data/'

# %%
nrows = 10
ncols = 20
step = 0.1
res = 5

# %%
def set_grid(nrows, ncols, step):
    grid = np.zeros((nrows*ncols, 2))
    # Calculate coordinates of grid points
    for i in range(nrows):
        for j in range(ncols):
            grid[i * ncols + j] = np.array((j*step, i*step))
            
    return grid

# %%
main_grid = set_grid(nrows, ncols, step)
sub_grid = set_grid((nrows-1)*res+1, (ncols-1)*res+1, step/res)

# %%
fig, axes = plt.subplots(figsize=(20,20))
axes.set_aspect('equal')
axes.axis('off')

# Draw coordinate grid points and gridlines between these points
axes.scatter(main_grid[:,0], main_grid[:,1],
             color='grey', s=10**2, zorder=2)
axes.scatter(sub_grid[:,0], sub_grid[:,1],
             color='green', s=3**2, alpha=0.5, zorder=2)
    
for i in range(ncols):
    axes.plot([i*step, i*step], [0, (nrows-1)*step],
              color='grey', ls='--', lw=2, zorder=1)
for i in range(nrows):
    axes.plot([0, (ncols-1)*step], [i*step, i*step],
              color='grey', ls='--', lw=2, zorder=1)

plt.show()
